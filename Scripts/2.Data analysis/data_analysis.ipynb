# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Some small data processing

# %%
climate = pd.read_csv("../../Data/climate-change_prepared.csv")
prodv = pd.read_csv("../../Data/production-vegetale_prepared.csv")

# %%
climate
# Out:
#    Year  AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.ZS  AG.LND.FRST.K2  \
# 0  2011      301038.000       67.451938       17.485548        56765.94
# 1  2012      304030.000       68.122339       18.030473        56786.18
# 2  2013      305850.000       68.530137       18.211965        56806.42
# 3  2014      300825.000       67.404212       17.031369        56826.66
# 4  2015      300470.000       67.324670       16.798790        56846.90
# 5  2016      308750.000       69.179924       18.420345        56997.90
# 6  2017      310465.482       69.564302       18.863453        57115.90
# 7  2018      305258.072       68.397507       17.593931        57215.90
# 8  2019      296119.070       66.349780       15.458131        57320.90
# 9  2020      303820.000       68.075286       17.138696        57424.90
#
#    AG.LND.FRST.ZS  AG.YLD.CREL.KG  BX.KLT.DINV.WD.GD.ZS  EG.ELC.ACCS.ZS  \
# 0       12.719234          1614.4              2.487275       93.446434
# ...

# %%
#columns_to_drop= ["BX.KLT.DINV.WD.GD.ZS","EG.ELC.ACCS.ZS","EG.FEC.RNEW.ZS","EN.ATM.GHGO.ZG","EN.URB.MCTY.TL.ZS","SH.DYN.MORT","SE.ENR.PRSC.FM.ZS","SE.PRM.CMPT.ZS","SP.URB.TOTL.IN.ZS"]
#climate =climate.drop(columns=columns_to_drop)

# %%
prodv['Filière'].unique()
# Out:
# array(['Agrumes', 'Amandiers', 'Céréales', 'Fourragères', 'Industrielles',
#        'Légumineuses', 'Maraîchage', 'Oliviers', 'Oléagineuses',
#        'Palmiers-Dattiers', 'Rosacées', 'Sucrières', 'Vignes'],
#       dtype=object)

# %%
prodv['Produit'].unique()
# Out:
# array(['Autres agrumes', 'Citron', 'Orange_Autres', 'Orange_Maroc late',
#        'Orange_Navel', 'Orange_Navel lane late', 'Orange_Navel late',
#        'Orange_Navelina', 'Orange_Salustiana',
#        'Orange_Washignton sanguine', 'Pamplemousse', 'Petit fruit_Autres',
#        'Petit fruit_Clémentine', 'Petit fruit_Fortune',
#        'Petit fruit_Nador cott', 'Petit fruit_Nour', 'Petit fruit_Nova',
#        'Petit fruit_Nules', 'Petit fruit_Ortanique', 'Amandier',
#        'Autres céréales', 'Avoine', 'Blé dur', 'Blé tendre', 'Mais',
#        'Orge', 'Riz', 'Sorgho', 'Avoine vert', 'Bersim', 'Lupin',
#        'Luzerne', 'Mais fourrager', 'Mélange fourrager', 'Orge fourrager',
#        'Pois fourrager', 'Sorgho fourrager', 'Triticale', 'Vesce avoine',
#        'Coriandre récoltée', 'Cornichon', 'Câprier', 'Henné',
#        'Piment de Cayenne', 'Rosier', 'Safran', 'Sorgho a balais',
#        'Autres légumineuses', 'Fève', 'Féverole', 'Lentille', 'Orobe',
# ...

# %%
#prodv = prodv[prodv['Filière'] == 'Céréales']
#prodv

# %%
prodv = prodv[prodv['Produit'] == 'Pomme de terre']
prodv
# Out:
#       Year     Filière         Produit    Production    Superficie
# 80    2011  Maraîchage  Pomme de terre  1.721402e+06  57846.220821
# 185   2012  Maraîchage  Pomme de terre  1.656891e+06  59216.900000
# 290   2013  Maraîchage  Pomme de terre  1.928606e+06  53047.600000
# 395   2014  Maraîchage  Pomme de terre  1.950982e+06  63514.500000
# 505   2015  Maraîchage  Pomme de terre  1.924430e+06  64515.000000
# 615   2016  Maraîchage  Pomme de terre  1.743616e+06  59434.500000
# 727   2017  Maraîchage  Pomme de terre  1.924872e+06  64293.000000
# 834   2018  Maraîchage  Pomme de terre  1.869149e+06  62033.000000
# 945   2019  Maraîchage  Pomme de terre  1.956711e+06  62462.500000
# 1057  2020  Maraîchage  Pomme de terre  1.707068e+06  57533.500000

# %%
pd.set_option('display.max_columns', None)

# %%
climate_prod_df = pd.merge(prodv, climate, on='Year')
climate_prod_df
# Out:
#    Year     Filière         Produit    Production    Superficie  \
# 0  2011  Maraîchage  Pomme de terre  1.721402e+06  57846.220821
# 1  2012  Maraîchage  Pomme de terre  1.656891e+06  59216.900000
# 2  2013  Maraîchage  Pomme de terre  1.928606e+06  53047.600000
# 3  2014  Maraîchage  Pomme de terre  1.950982e+06  63514.500000
# 4  2015  Maraîchage  Pomme de terre  1.924430e+06  64515.000000
# 5  2016  Maraîchage  Pomme de terre  1.743616e+06  59434.500000
# 6  2017  Maraîchage  Pomme de terre  1.924872e+06  64293.000000
# 7  2018  Maraîchage  Pomme de terre  1.869149e+06  62033.000000
# 8  2019  Maraîchage  Pomme de terre  1.956711e+06  62462.500000
# 9  2020  Maraîchage  Pomme de terre  1.707068e+06  57533.500000
#
#    AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.ZS  AG.LND.FRST.K2  \
# 0      301038.000       67.451938       17.485548        56765.94
# 1      304030.000       68.122339       18.030473        56786.18
# ...

# %% [markdown]
# # data analysis

# %%
climate_prod_df.shape
# Out:
# (10, 31)

# %%
climate_prod_df
# Out:
#    Year     Filière         Produit    Production    Superficie  \
# 0  2011  Maraîchage  Pomme de terre  1.721402e+06  57846.220821
# 1  2012  Maraîchage  Pomme de terre  1.656891e+06  59216.900000
# 2  2013  Maraîchage  Pomme de terre  1.928606e+06  53047.600000
# 3  2014  Maraîchage  Pomme de terre  1.950982e+06  63514.500000
# 4  2015  Maraîchage  Pomme de terre  1.924430e+06  64515.000000
# 5  2016  Maraîchage  Pomme de terre  1.743616e+06  59434.500000
# 6  2017  Maraîchage  Pomme de terre  1.924872e+06  64293.000000
# 7  2018  Maraîchage  Pomme de terre  1.869149e+06  62033.000000
# 8  2019  Maraîchage  Pomme de terre  1.956711e+06  62462.500000
# 9  2020  Maraîchage  Pomme de terre  1.707068e+06  57533.500000
#
#    AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.ZS  AG.LND.FRST.K2  \
# 0      301038.000       67.451938       17.485548        56765.94
# 1      304030.000       68.122339       18.030473        56786.18
# ...

# %%
climate_prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  10 non-null     int64
#  1   Filière               10 non-null     object
#  2   Produit               10 non-null     object
#  3   Production            10 non-null     float64
#  4   Superficie            10 non-null     float64
#  5   AG.LND.AGRI.K2        10 non-null     float64
#  6   AG.LND.AGRI.ZS        10 non-null     float64
#  7   AG.LND.ARBL.ZS        10 non-null     float64
#  8   AG.LND.FRST.K2        10 non-null     float64
#  9   AG.LND.FRST.ZS        10 non-null     float64
#  10  AG.YLD.CREL.KG        10 non-null     float64
#  11  BX.KLT.DINV.WD.GD.ZS  10 non-null     float64
#  12  EG.ELC.ACCS.ZS        10 non-null     float64
#  13  EG.FEC.RNEW.ZS        10 non-null     float64
# ...

# %%
#from sklearn.preprocessing import StandardScaler
## Standardize the selected columns
#scaler = StandardScaler()
#
## get columns to standardize
#cols_to_scale = [col for col in climate_prod_df.columns if col not in ['Year', 'Filière', 'Produit']]
#
#climate_prod_df[cols_to_scale] = scaler.fit_transform(climate_prod_df[cols_to_scale])
#climate_prod_df

# %%
corr_prod = climate_prod_df.corrwith(climate_prod_df[('Production')])

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_prod.to_frame(), cmap='coolwarm', annot=True, ax=ax)

# Set the title of the plot
ax.set_title('Correlation between Production and other variables')
# Out:
# Text(0.5, 1.0, 'Correlation between Production and other variables')

# %%
# Filter columns with correlation >= 0.01
high_corr_cols = corr_prod[abs(corr_prod) >= 0.5].index.tolist()

# Add Year, Filière, and Produit columns
final_cols = ['Year', 'Filière', 'Produit'] + high_corr_cols


# Drop columns with low correlation
climate_prod_df = climate_prod_df.loc[:, final_cols]
climate_prod_df
# Out:
#    Year     Filière         Produit    Production  AG.YLD.CREL.KG  \
# 0  2011  Maraîchage  Pomme de terre  1.721402e+06          1614.4
# 1  2012  Maraîchage  Pomme de terre  1.656891e+06          1016.6
# 2  2013  Maraîchage  Pomme de terre  1.928606e+06          1828.3
# 3  2014  Maraîchage  Pomme de terre  1.950982e+06          1454.3
# 4  2015  Maraîchage  Pomme de terre  1.924430e+06          2140.7
# 5  2016  Maraîchage  Pomme de terre  1.743616e+06           936.0
# 6  2017  Maraîchage  Pomme de terre  1.924872e+06          1757.6
# 7  2018  Maraîchage  Pomme de terre  1.869149e+06          2263.6
# 8  2019  Maraîchage  Pomme de terre  1.956711e+06          1454.1
# 9  2020  Maraîchage  Pomme de terre  1.707068e+06           742.9
#
#    EN.ATM.CO2E.KD.GD  EN.ATM.CO2E.PP.GD.KD  EN.ATM.METH.KT.CE  \
# 0           0.677687              0.276731       11010.000229
# 1           0.683052              0.278922       11100.000381
# ...

# %%
corr_prod = climate_prod_df.corrwith(climate_prod_df[('Production')])

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_prod[1:].to_frame(), cmap='coolwarm', annot=True, ax=ax)

# Set the title of the plot
ax.set_title('Correlation between Production and other variables')
# Out:
# Text(0.5, 1.0, 'Correlation between Production and other variables')

# %%
# Perform PCA
#from sklearn.decomposition import PCA
#
#pca = PCA(n_components=2)
#
#climate_prod_df_scl = climate_prod_df.drop(columns=['Year','Filière','Produit'])
#X_pca = pca.fit_transform(climate_prod_df_scl)
#
## Create scatter plot
#plt.scatter(X_pca[:,0], X_pca[:,1])
#
##sns.regplot(x=X_pca[:,0], y=X_pca[:,1], scatter=False, color='r')
#
#plt.xlabel('PC1')
#plt.ylabel('PC2')
#plt.show()

# %%
climate_prod_df.columns[3:]
# Out:
# Index(['Production', 'AG.YLD.CREL.KG', 'EN.ATM.CO2E.KD.GD',
#        'EN.ATM.CO2E.PP.GD.KD', 'EN.ATM.METH.KT.CE', 'EN.ATM.NOXE.KT.CE'],
#       dtype='object')

# %%
sns.set(style="ticks")
sns.pairplot(climate_prod_df, vars=climate_prod_df.columns[3:]) #[:-3]

# %%
climate_prod_df.to_csv("../../Data/climate-prod_merged.csv", index=False)
